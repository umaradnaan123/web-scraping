# %%
import requests
from bs4 import BeautifulSoup

# %%
web = requests.get('https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox')

# %%
web.content
# Out:
# b'<!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">c-wiz{contain:style}c-wiz>c-data{display:none}c-wiz.rETSD{contain:none}c-wiz.Ubi8Z{contain:layout style}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-50%,-50%) scale(2.2);-webkit-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2)}}@keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(
# ...

# %%
web.url
# Out:
# 'https://accounts.google.com/v3/signin/identifier?continue=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F%3Ftab%3Drm%26ogbl&emr=1&followup=https%3A%2F%2Fmail.google.com%2Fmail%2Fu%2F0%2F%3Ftab%3Drm%26ogbl&ifkv=ASKXGp39oP__-1xRtKPM1NTYcFda_OsQ2BQcouu0FWMA9w_ANp4_2c8GC0FtdKWQ0seICdwd6dIb2g&osid=1&passive=1209600&service=mail&flowName=WebLiteSignIn&flowEntry=ServiceLogin&dsh=S-2046039956%3A1705209207465590#inbox'

# %%
a = BeautifulSoup(web.content,"html.parser")

# %%
print(a)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
web.status_code
# Out:
# 200

# %%
a.title
# Out:
# <title>Gmail</title>

# %%
a.a
# Out:
# <a href="/signin/usernamerecovery?continue=https://mail.google.com/mail/u/0/?tab%3Drm%26ogbl&amp;dsh=S-2046039956:1705209207465590&amp;emr=1&amp;flowEntry=ServiceLogin&amp;flowName=WebLiteSignIn&amp;followup=https://mail.google.com/mail/u/0/?tab%3Drm%26ogbl&amp;ifkv=ASKXGp39oP__-1xRtKPM1NTYcFda_OsQ2BQcouu0FWMA9w_ANp4_2c8GC0FtdKWQ0seICdwd6dIb2g&amp;osid=1&amp;service=mail" jsname="Cuz2Ue">Forgot email?</a>

# %%
a.h1
# Out:
# <h1 class="Tn0LBd" jsname="r4nke">Sign in</h1>

# %%
a.link
print(a)
# Out:
# <!DOCTYPE html>
# ...

# %%
a.img
# Out:
# <img alt="Google" class="TrZEUc" height="24" src="//ssl.gstatic.com/images/branding/googlelogo/2x/googlelogo_color_74x24dp.png" width="74"/>

# %%
a.scr
print(a)
# Out:
# <!DOCTYPE html>
# ...

# %%
a.href
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.p
# Out:
# <p class="a2CQh" jsname="VdSJob">to continue to Gmail</p>

# %%
a.find_all("img")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.script
# Out:
# <script nonce="0t3crCUHJ0LQcfYmu8_ERA">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==
# ...

# %%
Tag = a.html
print(Tag)
# Out:
# <html dir="ltr" lang="en-US"><head><base href="https://accounts.google.com/v3/signin/"/><meta content="origin" name="referrer"/><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">c-wiz{contain:style}c-wiz>c-data{display:none}c-wiz.rETSD{contain:none}c-wiz.Ubi8Z{contain:layout style}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scale(0.2)}to{-webkit-transform:translate(-50%,-50%) scale(2.2);-webkit-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2)}}@keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%,-50%) scale(0.2);-webkit-transform:translate(-50%,-50%) scale(0.2);transform:translate(-50%,-50%) scal
# ...

# %%
Tag = a.string
print(Tag)
# Out:
# None

# %%
Tag = a.script
print(Tag)
# Out:
# <script nonce="0t3crCUHJ0LQcfYmu8_ERA">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJlRHluYW1pY0J1dHRvbiJdLCJtYXBwaW5ncyI6IkFBQUE7QUFBQTtBQUFBO0FBQUE7QUFBQTtBQUFBO0FBQUEifQ==
# ...

# %%
com = a.p.string
print(com)
# Out:
# to continue to Gmail

# %%
a.find_all("href")
print(a)
# Out:
# <!DOCTYPE html>
# ...

# %%
a.find_all("href")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.find_all("img")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.find_all("scr")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.find_all("h1")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
a.find_all("p")
print(a.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <base href="https://accounts.google.com/v3/signin/"/>
#   <meta content="origin" name="referrer"/>
#   <style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.TdAiKl2si0A.L.W.O/am=P8BCEo4FoAwBaAAAAgAFCgAAAAAAIAAAQANYQg/d=1/ed=1/rs=AOaEmlGyB8YwGRstvY47maOtmFGnHRQMKw/m=identifierview,_b,_tp" nonce="gA_rjcSXgIXKl15WU_FXtw">
# ...

# %%
com = a.h1.string
print(com)
# Out:
# Sign in
